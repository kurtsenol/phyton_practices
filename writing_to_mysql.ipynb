# %% [markdown]
# <a href="https://colab.research.google.com/github/kurtsenol/python_practices/blob/master/writing_to_mysql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install mysql-connector-python
# Out:
# ...
#      |████████████████████████████████| 15.8MB 277kB/s
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bba2ccfa-bfba-410d-90cc-0cf3d339e0b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bba2ccfa-bfba-410d-90cc-0cf3d339e0b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
import pandas as pd
import mysql.connector

from sqlalchemy import create_engine

hostname = "34.68.130.89"
username = "pmca"
password = "password123"
database = "pmc_db"
# Open database connection
engine = create_engine('mysql+mysqlconnector://pmca:password123@34.68.130.89:3306/pmc_db', echo=False)

# %%
df_employees = pd.read_csv("/content/employees.csv")
df_employees
# Out:
#     employee_id  first_name   last_name  ... office_id  task_id  project
# 0         33391      D'arcy    Nortunen  ...         1        1    Alpha
# 1         37270    Yovonnda  Magrannell  ...        10        2    Alpha
# 2         37851       Sayer   Matterson  ...         1        2    Alpha
# 3         40448       Mindy     Crissil  ...         1        3    Alpha
# 4         56274     Keriann     Alloisi  ...         1        2    Alpha
# 5         63196     Alaster    Scutchin  ...         2        4    Alpha
# 6         67009       North    de Clerc  ...         2        2    Alpha
# 7         67370    Elladine      Rising  ...         2        4    Alpha
# 8         68249       Nisse      Voysey  ...         2        1    Alpha
# 9         72540     Guthrey   Iacopetti  ...         3        4    Alpha
# 10        72913        Kass    Hefferan  ...         3        4     Beta
# 11        75900       Virge     Goodrum  ...         3        3     Beta
# ...

# %%
# df_employees.to_sql('employees', con=engine, if_exists='replace', index = False)

# %%
df_tasks = pd.read_csv("/content/tasks.csv")
df_tasks
# Out:
#    task_id                           task_name
# 0        1                Plan Risk Management
# 1        2                      Identify Risks
# 2        3    Perform Qualtative Risk Analysis
# 3        4  Perform Quantitative Risk Analysis

# %%
# df_tasks.to_sql('tasks', con=engine, if_exists='replace', index = False)

# %%
query = """SELECT * FROM employees;"""

df_1 = pd.read_sql(query, con=engine)
df_1
# Out:
#     employee_id  first_name   last_name  ... office_id  task_id  project
# 0         33391      D'arcy    Nortunen  ...         1        1    Alpha
# 1         37270    Yovonnda  Magrannell  ...        10        2    Alpha
# 2         37851       Sayer   Matterson  ...         1        2    Alpha
# 3         40448       Mindy     Crissil  ...         1        3    Alpha
# 4         56274     Keriann     Alloisi  ...         1        2    Alpha
# 5         63196     Alaster    Scutchin  ...         2        4    Alpha
# 6         67009       North    de Clerc  ...         2        2    Alpha
# 7         67370    Elladine      Rising  ...         2        4    Alpha
# 8         68249       Nisse      Voysey  ...         2        1    Alpha
# 9         72540     Guthrey   Iacopetti  ...         3        4    Alpha
# 10        72913        Kass    Hefferan  ...         3        4     Beta
# 11        75900       Virge     Goodrum  ...         3        3     Beta
# ...

# %%
query = """SELECT * FROM tasks;"""

df_2 = pd.read_sql(query, con=engine)
df_2
# Out:
#    task_id                           task_name
# 0        1                Plan Risk Management
# 1        2                      Identify Risks
# 2        3    Perform Qualtative Risk Analysis
# 3        4  Perform Quantitative Risk Analysis

# %%
query = """SELECT * FROM tasks;"""

# %%
project_name ="Alpha"

if project_name:
  with engine.connect() as con:
    results = con.execute(f"""SELECT first_name, last_name FROM employees WHERE project='{project_name}'""").fetchall()

  if len(results) != 0:
    for row in results:
      print(row)
# Out:
# ("D'arcy", 'Nortunen')
# ('Yovonnda', 'Magrannell')
# ('Sayer', 'Matterson')
# ('Mindy', 'Crissil')
# ('Keriann', 'Alloisi')
# ('Alaster', 'Scutchin')
# ('North', 'de Clerc')
# ('Elladine', 'Rising')
# ('Nisse', 'Voysey')
# ('Guthrey', 'Iacopetti')
